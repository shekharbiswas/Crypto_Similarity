# %%
"""
CRYPTO INDICATOR PROCESSOR — WEEKLY
=====================================
Reads crypto_top500_2yr.csv (or any per-coin CSVs in crypto_data/),
resamples daily OHLCV → weekly (week ending Friday),
calculates all technical indicators,
and saves to weekly_crypto_with_indicators.csv

Input columns : date, open, high, low, close, volume_usd, symbol, ...
Output        : all input cols + 50+ indicators + surge_score (weekly cadence)
"""

import pandas as pd
import numpy as np
import warnings
import time
import os
warnings.filterwarnings('ignore')


# ============================================================================
# WEEKLY RESAMPLING
# ============================================================================

def resample_to_weekly(df: pd.DataFrame) -> pd.DataFrame:
    """
    Resample a single-coin daily DataFrame to weekly OHLCV.
    Week anchor: Friday ('W-FRI') — each row represents the week ending that Friday.

    Aggregation rules:
      open        → first day's open  (handles partial weeks at start/end)
      high        → max of week
      low         → min of week
      close       → last day's close
      volume_usd  → sum of week
      Metadata    → last value (constant per coin)

    Partial-week handling
    ─────────────────────
    pandas W-FRI always anchors to the NEXT Friday.  If a coin's data starts on
    a Wednesday, the first bucket contains only Wed–Fri — that is a valid partial
    week and must be KEPT (not dropped), because dropping it silently removes the
    coin's earliest bars and can shrink the history enough to fall under the
    minimum-bar threshold, causing the coin to be excluded entirely.

    We therefore use dropna(subset=["close"]) ONLY to remove calendar weeks that
    genuinely have zero trading data (e.g. exchange outages), NOT partial weeks.
    Partial weeks always have a valid close, so they pass through naturally.
    """
    df = df.set_index("date")

    ohlcv_agg = {
        "open":       "first",
        "high":       "max",
        "low":        "min",
        "close":      "last",
        "volume_usd": "sum",
    }

    # All non-OHLCV, non-symbol columns — carry forward last value
    meta_cols = [
        c for c in df.columns
        if c not in ohlcv_agg and c not in ("symbol",)
        and df[c].dtype in (object, "category", float, int, np.float64, np.int64)
    ]
    meta_agg  = {c: "last" for c in meta_cols}
    agg_rules = {k: v for k, v in {**ohlcv_agg, **meta_agg}.items() if k in df.columns}

    weekly = df.resample("W-FRI").agg(agg_rules)

    # Drop only calendar weeks with NO trading data at all (close is NaN)
    # Partial weeks (Mon/Wed start) already have a valid close and are kept.
    weekly = weekly.dropna(subset=["close"])

    # Ensure open is never NaN (can happen if a week has close but open fell
    # through due to all-NaN days in the open column)
    if "open" in weekly.columns:
        weekly["open"] = weekly["open"].fillna(weekly["close"])

    weekly = weekly.reset_index()
    # resample() names the index after the original index — normalise to "date"
    if weekly.columns[0] != "date":
        weekly = weekly.rename(columns={weekly.columns[0]: "date"})

    return weekly


# ============================================================================
# SURGE SCORE HELPERS
# ============================================================================

MOMENTUM_INDICATORS = ['RSI', 'Stoch_K', 'Stoch_D', 'Williams_R', 'CCI', 'ROC_14', 'TSI']
SURGE_LOOKBACK  = 3   # 3 weeks
SURGE_THRESHOLD = 10

# ~52 weeks ≈ 1 year  (was 252 days in the daily version)
NORMALIZE_WINDOW = 52

def _normalize_indicator(series, window=NORMALIZE_WINDOW):
    series = series.fillna(series.median())
    rolling_min = series.rolling(window, min_periods=10).min()
    rolling_max = series.rolling(window, min_periods=10).max()
    return ((series - rolling_min) / (rolling_max - rolling_min)).clip(0, 1).mul(100).fillna(50)

def _get_momentum_score(df):
    vals, weights = [], []
    for col in MOMENTUM_INDICATORS:
        if col in df.columns:
            vals.append(_normalize_indicator(df[col]))
            weights.append(1)
    if vals:
        return sum(vals) / sum(weights)
    return pd.Series(50.0, index=df.index)

def _compute_surge_score(momentum_series, lookback=SURGE_LOOKBACK):
    abs_chg = momentum_series.diff(lookback)
    pct_chg = momentum_series.pct_change(lookback) * 100
    accel   = momentum_series.diff().diff()
    mean    = momentum_series.rolling(20, min_periods=5).mean()
    std     = momentum_series.rolling(20, min_periods=5).std()
    z       = (momentum_series - mean) / (std + 1e-10)

    score = pd.Series(0.0, index=momentum_series.index)
    for i in range(lookback, len(momentum_series)):
        score.iloc[i] = (
            abs_chg.iloc[i] * 0.4 +
            (pct_chg.iloc[i] if not pd.isna(pct_chg.iloc[i]) else 0) * 0.3 +
            (accel.iloc[i]   if not pd.isna(accel.iloc[i])   else 0) * 2.0 +
            (z.iloc[i]       if not pd.isna(z.iloc[i])        else 0) * 3.0
        )
    return score


# ============================================================================
# TECHNICAL INDICATORS
# ============================================================================

class TechnicalIndicators:

    @staticmethod
    def calculate_all(df):
        ind = TechnicalIndicators

        # ── Trend ──────────────────────────────────────────────────────────────
        df['EMA_9']   = df['close'].ewm(span=9,   adjust=False).mean()
        df['EMA_21']  = df['close'].ewm(span=21,  adjust=False).mean()
        df['EMA_50']  = df['close'].ewm(span=50,  adjust=False).mean()
        df['EMA_100'] = df['close'].ewm(span=100, adjust=False).mean()
        df['EMA_200'] = df['close'].ewm(span=200, adjust=False).mean()
        df['SMA_50']  = df['close'].rolling(50).mean()
        df['SMA_200'] = df['close'].rolling(200).mean()

        # ── Bollinger Bands ────────────────────────────────────────────────────
        df['BB_Middle']  = df['close'].rolling(20).mean()
        bb_std           = df['close'].rolling(20).std()
        df['BB_Upper']   = df['BB_Middle'] + bb_std * 2
        df['BB_Lower']   = df['BB_Middle'] - bb_std * 2
        df['BB_Width']   = (df['BB_Upper'] - df['BB_Lower']) / df['BB_Middle'].replace(0, np.nan)
        df['BB_Percent'] = (df['close'] - df['BB_Lower']) / (df['BB_Upper'] - df['BB_Lower']).replace(0, np.nan)

        # ── Keltner Channels ───────────────────────────────────────────────────
        df['KC_Middle'] = df['close'].ewm(span=20, adjust=False).mean()
        atr_kc          = ind.calculate_atr(df, 20)
        df['KC_Upper']  = df['KC_Middle'] + atr_kc * 2
        df['KC_Lower']  = df['KC_Middle'] - atr_kc * 2

        # ── Donchian Channels ──────────────────────────────────────────────────
        df['DC_Upper']  = df['high'].rolling(20).max()
        df['DC_Lower']  = df['low'].rolling(20).min()
        df['DC_Middle'] = (df['DC_Upper'] + df['DC_Lower']) / 2

        # ── Pivot Points ───────────────────────────────────────────────────────
        df['Pivot'] = (df['high'].shift(1) + df['low'].shift(1) + df['close'].shift(1)) / 3
        df['R1']    = 2 * df['Pivot'] - df['low'].shift(1)
        df['S1']    = 2 * df['Pivot'] - df['high'].shift(1)
        df['R2']    = df['Pivot'] + (df['high'].shift(1) - df['low'].shift(1))
        df['S2']    = df['Pivot'] - (df['high'].shift(1) - df['low'].shift(1))

        # ── VWAP (weekly: volume_usd is already weekly sum) ────────────────────
        df['VWAP'] = (
            df['volume_usd'] * (df['high'] + df['low'] + df['close']) / 3
        ).cumsum() / df['volume_usd'].cumsum()

        # ── Supertrend ─────────────────────────────────────────────────────────
        st = ind.calculate_supertrend(df)
        df['Supertrend']           = st['Supertrend']
        df['Supertrend_Direction'] = st['Direction']

        # ── Parabolic SAR ──────────────────────────────────────────────────────
        psar = ind.calculate_psar(df)
        df['PSAR']       = psar['PSAR']
        df['PSAR_Trend'] = psar['Trend']

        # ── Ichimoku ───────────────────────────────────────────────────────────
        for k, v in ind.calculate_ichimoku(df).items():
            df[k] = v

        # ── Momentum ───────────────────────────────────────────────────────────
        df['RSI']        = ind.calculate_rsi(df['close'], 14)
        stoch            = ind.calculate_stochastic(df)
        df['Stoch_K']    = stoch['K']
        df['Stoch_D']    = stoch['D']
        df['Williams_R'] = ind.calculate_williams_r(df)
        df['CCI']        = ind.calculate_cci(df)
        df['ROC_9']      = ((df['close'] - df['close'].shift(9))  / df['close'].shift(9).replace(0, np.nan))  * 100
        df['ROC_14']     = ((df['close'] - df['close'].shift(14)) / df['close'].shift(14).replace(0, np.nan)) * 100
        df['ROC_21']     = ((df['close'] - df['close'].shift(21)) / df['close'].shift(21).replace(0, np.nan)) * 100

        # ── MACD ───────────────────────────────────────────────────────────────
        macd             = ind.calculate_macd(df['close'])
        df['MACD']       = macd['MACD']
        df['MACD_Signal']= macd['Signal']
        df['MACD_Hist']  = macd['Histogram']

        # ── TSI ────────────────────────────────────────────────────────────────
        df['TSI'] = ind.calculate_tsi(df['close'])

        # ── Volume Indicators ──────────────────────────────────────────────────
        df['OBV']        = ind.calculate_obv(df)
        df['AD_Line']    = ind.calculate_ad_line(df)
        df['CMF']        = ind.calculate_cmf(df)
        df['MFI']        = ind.calculate_mfi(df)
        df['Volume_ROC'] = ((df['volume_usd'] - df['volume_usd'].shift(14)) / df['volume_usd'].shift(14).replace(0, np.nan)) * 100

        # ── Volatility ─────────────────────────────────────────────────────────
        df['ATR'] = ind.calculate_atr(df, 14)

        # ── Directional Movement ───────────────────────────────────────────────
        dm             = ind.calculate_dm(df)
        df['PLUS_DI']  = dm['PLUS_DI']
        df['MINUS_DI'] = dm['MINUS_DI']
        df['ADX']      = dm['ADX']

        # ── Aroon ──────────────────────────────────────────────────────────────
        aroon                  = ind.calculate_aroon(df)
        df['Aroon_Up']         = aroon['Aroon_Up']
        df['Aroon_Down']       = aroon['Aroon_Down']
        df['Aroon_Oscillator'] = aroon['Aroon_Oscillator']

        # ── Price Structure ────────────────────────────────────────────────────
        df['Higher_Highs'] = (df['high'] > df['high'].shift(1)).astype(int)
        df['Higher_Lows']  = (df['low']  > df['low'].shift(1)).astype(int)

        # ── Future Returns — now in weekly units ───────────────────────────────
        df['Next_1w_Return'] = ((df['close'].shift(-1) - df['close']) / df['close']) * 100
        df['Next_2w_Return'] = ((df['close'].shift(-2) - df['close']) / df['close']) * 100
        df['Next_3w_Return'] = ((df['close'].shift(-3) - df['close']) / df['close']) * 100
        df['Next_4w_Return'] = ((df['close'].shift(-4) - df['close']) / df['close']) * 100
        df['Next_8w_Return'] = ((df['close'].shift(-8) - df['close']) / df['close']) * 100

        # ── Surge Score ────────────────────────────────────────────────────────
        momentum_composite = _get_momentum_score(df)
        df['surge_score']  = _compute_surge_score(momentum_composite, lookback=SURGE_LOOKBACK)

        return df

    # ── Individual indicator methods ──────────────────────────────────────────

    @staticmethod
    def calculate_atr(df, period=14):
        hl        = df['high'] - df['low']
        hc        = np.abs(df['high'] - df['close'].shift())
        lc        = np.abs(df['low']  - df['close'].shift())
        tr        = pd.concat([hl, hc, lc], axis=1).max(axis=1)
        return tr.rolling(period).mean()

    @staticmethod
    def calculate_supertrend(df, period=10, multiplier=3):
        atr    = TechnicalIndicators.calculate_atr(df, period)
        hl_avg = (df['high'] + df['low']) / 2
        upper  = hl_avg + multiplier * atr
        lower  = hl_avg - multiplier * atr

        supertrend = pd.Series(index=df.index, dtype=float)
        direction  = pd.Series(index=df.index, dtype=int)
        supertrend.iloc[0] = lower.iloc[0]
        direction.iloc[0]  = 1

        for i in range(1, len(df)):
            if direction.iloc[i-1] == 1:
                cur_lower = max(lower.iloc[i], supertrend.iloc[i-1])
            else:
                cur_lower = lower.iloc[i]
            if direction.iloc[i-1] == -1:
                cur_upper = min(upper.iloc[i], supertrend.iloc[i-1])
            else:
                cur_upper = upper.iloc[i]

            if df['close'].iloc[i] > supertrend.iloc[i-1]:
                supertrend.iloc[i] = cur_lower
                direction.iloc[i]  = 1
            else:
                supertrend.iloc[i] = cur_upper
                direction.iloc[i]  = -1

        return {'Supertrend': supertrend, 'Direction': direction}

    @staticmethod
    def calculate_psar(df, iaf=0.02, maxaf=0.2):
        psar  = df['close'].copy()
        trend = pd.Series(index=df.index, dtype=int)
        bull  = True
        af    = iaf
        hp    = df['high'].iloc[0]
        lp    = df['low'].iloc[0]
        trend.iloc[0] = 1

        for i in range(2, len(df)):
            if bull:
                psar.iloc[i] = psar.iloc[i-1] + af * (hp - psar.iloc[i-1])
            else:
                psar.iloc[i] = psar.iloc[i-1] + af * (lp - psar.iloc[i-1])

            reverse = False
            if bull:
                if df['low'].iloc[i] < psar.iloc[i]:
                    bull = False; reverse = True
                    psar.iloc[i] = hp; lp = df['low'].iloc[i]; af = iaf
            else:
                if df['high'].iloc[i] > psar.iloc[i]:
                    bull = True; reverse = True
                    psar.iloc[i] = lp; hp = df['high'].iloc[i]; af = iaf

            if not reverse:
                if bull:
                    if df['high'].iloc[i] > hp:
                        hp = df['high'].iloc[i]; af = min(af + iaf, maxaf)
                    if df['low'].iloc[i-1] < psar.iloc[i]: psar.iloc[i] = df['low'].iloc[i-1]
                    if df['low'].iloc[i-2] < psar.iloc[i]: psar.iloc[i] = df['low'].iloc[i-2]
                else:
                    if df['low'].iloc[i] < lp:
                        lp = df['low'].iloc[i]; af = min(af + iaf, maxaf)
                    if df['high'].iloc[i-1] > psar.iloc[i]: psar.iloc[i] = df['high'].iloc[i-1]
                    if df['high'].iloc[i-2] > psar.iloc[i]: psar.iloc[i] = df['high'].iloc[i-2]

            trend.iloc[i] = 1 if bull else -1

        return {'PSAR': psar, 'Trend': trend}

    @staticmethod
    def calculate_ichimoku(df):
        t = (df['high'].rolling(9).max()  + df['low'].rolling(9).min())  / 2
        k = (df['high'].rolling(26).max() + df['low'].rolling(26).min()) / 2
        return {
            'Ichimoku_Tenkan': t,
            'Ichimoku_Kijun':  k,
            'Ichimoku_SpanA':  ((t + k) / 2).shift(26),
            'Ichimoku_SpanB':  ((df['high'].rolling(52).max() + df['low'].rolling(52).min()) / 2).shift(26),
        }

    @staticmethod
    def calculate_rsi(series, period=14):
        delta = series.diff()
        gain  = delta.where(delta > 0, 0).rolling(period).mean()
        loss  = (-delta.where(delta < 0, 0)).rolling(period).mean()
        return 100 - (100 / (1 + gain / loss.replace(0, np.nan)))

    @staticmethod
    def calculate_stochastic(df, k=14, d=3):
        lo = df['low'].rolling(k).min()
        hi = df['high'].rolling(k).max()
        K  = 100 * ((df['close'] - lo) / (hi - lo).replace(0, np.nan))
        return {'K': K, 'D': K.rolling(d).mean()}

    @staticmethod
    def calculate_williams_r(df, period=14):
        hi = df['high'].rolling(period).max()
        lo = df['low'].rolling(period).min()
        return -100 * ((hi - df['close']) / (hi - lo).replace(0, np.nan))

    @staticmethod
    def calculate_cci(df, period=20):
        tp  = (df['high'] + df['low'] + df['close']) / 3
        sma = tp.rolling(period).mean()
        mad = tp.rolling(period).apply(lambda x: np.abs(x - x.mean()).mean())
        return (tp - sma) / (0.015 * mad).replace(0, np.nan)

    @staticmethod
    def calculate_macd(series, fast=12, slow=26, signal=9):
        m = series.ewm(span=fast, adjust=False).mean() - series.ewm(span=slow, adjust=False).mean()
        s = m.ewm(span=signal, adjust=False).mean()
        return {'MACD': m, 'Signal': s, 'Histogram': m - s}

    @staticmethod
    def calculate_tsi(series, long=25, short=13):
        pc  = series.diff()
        ds  = pc.ewm(span=long, adjust=False).mean().ewm(span=short, adjust=False).mean()
        dsa = pc.abs().ewm(span=long, adjust=False).mean().ewm(span=short, adjust=False).mean()
        return 100 * (ds / dsa.replace(0, np.nan))

    @staticmethod
    def calculate_obv(df):
        obv = [0]
        for i in range(1, len(df)):
            if df['close'].iloc[i] > df['close'].iloc[i-1]:
                obv.append(obv[-1] + df['volume_usd'].iloc[i])
            elif df['close'].iloc[i] < df['close'].iloc[i-1]:
                obv.append(obv[-1] - df['volume_usd'].iloc[i])
            else:
                obv.append(obv[-1])
        return pd.Series(obv, index=df.index)

    @staticmethod
    def calculate_ad_line(df):
        clv = ((df['close'] - df['low']) - (df['high'] - df['close'])) / (df['high'] - df['low']).replace(0, np.nan)
        return (clv.fillna(0) * df['volume_usd']).cumsum()

    @staticmethod
    def calculate_cmf(df, period=20):
        mfm = ((df['close'] - df['low']) - (df['high'] - df['close'])) / (df['high'] - df['low']).replace(0, np.nan)
        mfv = mfm.fillna(0) * df['volume_usd']
        return mfv.rolling(period).sum() / df['volume_usd'].rolling(period).sum().replace(0, np.nan)

    @staticmethod
    def calculate_mfi(df, period=14):
        tp  = (df['high'] + df['low'] + df['close']) / 3
        rmf = tp * df['volume_usd']
        pos = pd.Series(0.0, index=df.index)
        neg = pd.Series(0.0, index=df.index)
        for i in range(1, len(df)):
            if   tp.iloc[i] > tp.iloc[i-1]: pos.iloc[i] = rmf.iloc[i]
            elif tp.iloc[i] < tp.iloc[i-1]: neg.iloc[i] = rmf.iloc[i]
        mfi = 100 - (100 / (1 + pos.rolling(period).sum() / neg.rolling(period).sum().replace(0, np.nan)))
        return mfi.fillna(50)

    @staticmethod
    def calculate_dm(df, period=14):
        hd = df['high'].diff()
        ld = -df['low'].diff()
        pdm = pd.Series(0.0, index=df.index)
        mdm = pd.Series(0.0, index=df.index)
        pdm[(hd > ld) & (hd > 0)] = hd
        mdm[(ld > hd) & (ld > 0)] = ld
        atr     = TechnicalIndicators.calculate_atr(df, period)
        pdi     = 100 * pdm.rolling(period).mean() / atr.replace(0, np.nan)
        mdi     = 100 * mdm.rolling(period).mean() / atr.replace(0, np.nan)
        dx      = 100 * np.abs(pdi - mdi) / (pdi + mdi).replace(0, np.nan)
        return {'PLUS_DI': pdi, 'MINUS_DI': mdi, 'ADX': dx.rolling(period).mean()}

    @staticmethod
    def calculate_aroon(df, period=25):
        def up(x):   return ((period - (len(x) - 1 - np.argmax(x))) / period) * 100
        def down(x): return ((period - (len(x) - 1 - np.argmin(x))) / period) * 100
        au = df['high'].rolling(period + 1).apply(up,   raw=True)
        ad = df['low'].rolling(period + 1).apply(down,  raw=True)
        return {'Aroon_Up': au, 'Aroon_Down': ad, 'Aroon_Oscillator': au - ad}


# ============================================================================
# MAIN PROCESSING
# ============================================================================

def process_crypto_data_weekly(input_csv: str, output_csv: str = "weekly_crypto_with_indicators.csv"):
    print("=" * 70)
    print("CRYPTO INDICATOR PROCESSOR — WEEKLY")
    print("=" * 70)

    if not os.path.exists(input_csv):
        print(f"❌ File not found: {input_csv}")
        return None

    print(f"\n📂 Reading: {input_csv}")
    df = pd.read_csv(input_csv, parse_dates=["date"])
    df = df.sort_values(["symbol", "date"]).reset_index(drop=True)

    # Drop old partial indicator columns (will be recomputed cleanly)
    old_indicator_cols = [
        "daily_return_pct","candle_range_pct","ma_20","ma_50","ma_200",
        "vol_ma_20","rel_volume","rsi_14","bb_upper","bb_lower","bb_pct",
        "macd","macd_signal","macd_hist","bb_mid","bb_std"
    ]
    df = df.drop(columns=[c for c in old_indicator_cols if c in df.columns])

    symbols = df["symbol"].unique()
    print(f"✓ Loaded {len(df):,} daily rows | {len(symbols)} coins")
    print(f"  Resampling daily → weekly (W-FRI anchor)...\n")

    all_data   = []
    successful = 0
    failed     = 0
    start      = time.time()

    print("=" * 70)
    for idx, symbol in enumerate(symbols, 1):
        try:
            coin_df = df[df["symbol"] == symbol].copy().reset_index(drop=True)

            # ── Resample to weekly ─────────────────────────────────────────────
            weekly_df = resample_to_weekly(coin_df)
            weekly_df["symbol"] = symbol   # restore symbol column

            # Need at least 26 weekly bars (≈ 6 months) for meaningful indicators.
            # The old threshold was 50 (≈ 1 year), which silently excluded coins
            # listed within the past year even when they had months of valid data.
            # 26 bars is enough for RSI(14), Stoch(14), BB(20) to warm up fully,
            # and any coin with fewer bars genuinely lacks enough history.
            if len(weekly_df) < 26:
                print(
                    f"[{idx:3d}/{len(symbols)}] ⚠  {symbol:12s} — "
                    f"only {len(weekly_df)} weekly bars after resampling, skipping (need 26+)"
                )
                failed += 1
                continue

            weekly_df = TechnicalIndicators.calculate_all(weekly_df)
            all_data.append(weekly_df)
            successful += 1

            latest = weekly_df.iloc[-1]
            print(
                f"[{idx:3d}/{len(symbols)}] ✓ {symbol:12s} | "
                f"{len(weekly_df):3d} weeks | "
                f"RSI: {latest.get('RSI', float('nan')):.1f} | "
                f"surge: {latest.get('surge_score', float('nan')):.2f}"
            )

        except Exception as e:
            print(f"[{idx:3d}/{len(symbols)}] ❌ {symbol:12s} — {str(e)[:60]}")
            failed += 1

    print("=" * 70)

    if not all_data:
        print("❌ No data processed.")
        return None

    print(f"\n💾 Merging and saving...")
    out = pd.concat(all_data, ignore_index=True)
    out = out.sort_values(["symbol", "date"]).reset_index(drop=True)
    out.to_csv(output_csv, index=False)

    elapsed = time.time() - start

    # Summary
    basic  = ["date","open","high","low","close","volume_usd","symbol","name","coin_id"]
    meta   = ["market_cap_usd","cap_tier","ath","atl","circulating_supply","max_supply",
              "change_24h_pct","volume_24h_usd","is_stablecoin","pair"]
    future = [c for c in out.columns if c.startswith("Next_")]
    indic  = [c for c in out.columns if c not in basic + meta + future]

    print(f"\n{'='*70}")
    print("SUMMARY")
    print(f"{'='*70}")
    print(f"✅ Successful : {successful} coins")
    print(f"❌ Failed     : {failed} coins")
    print(f"📊 Total rows : {len(out):,}  (weekly bars)")
    print(f"📅 Date range : {out['date'].min().date()} → {out['date'].max().date()}")
    print(f"⏱  Time       : {elapsed:.1f}s ({elapsed/60:.1f} min)")
    print(f"\nColumn breakdown:")
    print(f"  OHLCV + meta  : {len(basic + meta)}")
    print(f"  Indicators    : {len(indic)}  ← includes surge_score")
    print(f"  Future returns: {len(future)}  (Next_1w … Next_8w)")
    print(f"  TOTAL         : {len(out.columns)}")
    print(f"\n📁 Output: {output_csv}")
    print(f"   Size  : {out.memory_usage(deep=True).sum() / 1024 / 1024:.1f} MB")

    return out


if __name__ == "__main__":
    INPUT_CSV  = "crypto_top500_2yr.csv"
    OUTPUT_CSV = "weekly_crypto_with_indicators.csv"

    result = process_crypto_data_weekly(INPUT_CSV, OUTPUT_CSV)
# Out:
# ======================================================================
# CRYPTO INDICATOR PROCESSOR — WEEKLY
# ======================================================================
#
# 📂 Reading: crypto_top500_2yr.csv
# ✓ Loaded 123,310 daily rows | 213 coins
#   Resampling daily → weekly (W-FRI anchor)...
#
# ======================================================================
# [  1/213] ✓ 0G           |  26 weeks | RSI: 36.9 | surge: -23.42
# [  2/213] ✓ 1INCH        | 105 weeks | RSI: 20.0 | surge: 3.19
# [  3/213] ⚠  2Z           — only 25 weekly bars after resampling, skipping (need 26+)
# [  4/213] ✓ A            |  43 weeks | RSI: 18.2 | surge: 7.70
# [  5/213] ✓ AAVE         | 105 weeks | RSI: 19.9 | surge: -16.84
# [  6/213] ✓ ADA          | 105 weeks | RSI: 24.5 | surge: 4.12
# [  7/213] ✓ AEUR         | 105 weeks | RSI: 46.9 | surge: -0.24
# [  8/213] ✓ ALGO         | 105 weeks | RSI: 31.2 | surge: -1.32
# [  9/213] ✓ AMP          | 105 weeks | RSI: 28.0 | surge: -27.42
# [ 10/213] ✓ ANKR         | 105 weeks | RSI: 29.7 | surge: 69.35
# [ 11/213] ✓ APE          | 105 weeks | RSI: 9.2 | surge: -1.51
# [ 12/213] ✓ APT          | 105 weeks | RSI: 27.7 | surge: 38.84
# [ 13/213] ✓ AR           | 105 weeks | RSI: 22.7 | surge: -14.52
# [ 14/213] ✓ ARB          | 105 weeks | RSI: 16.2 | surge: -9.73
# [ 15/213] ✓ ARDR         | 105 weeks | RSI: 32.0 | surge: 17.36
# [ 16/213] ✓ ARKM         | 105 weeks | RSI: 18.7 | surge: -4.84
# [ 17/213] ⚠  ASTER        — only 24 weekly bars after resampling, skipping (need 26+)
# [ 18/213] ✓ ASTR         | 105 weeks | RSI: 26.5 | surge: 43.70
# [ 19/213] ✓ ATOM         | 105 weeks | RSI: 43.1 | surge: -18.98
# [ 20/213] ✓ AVAX         | 105 weeks | RSI: 28.2 | surge: -1.61
# [ 21/213] ✓ AVNT         |  27 weeks | RSI: 32.9 | surge: -42.80
# [ 22/213] ✓ AWE          |  44 weeks | RSI: 48.1 | surge: -14.77
# [ 23/213] ✓ AXL          | 105 weeks | RSI: 11.2 | surge: -37.44
# [ 24/213] ✓ AXS          | 105 weeks | RSI: 52.5 | surge: 3.96
# [ 25/213] ✓ BANANAS31    |  52 weeks | RSI: 73.8 | surge: -39.47
# [ 26/213] ✓ BARD         |  27 weeks | RSI: 40.4 | surge: -101.52
# [ 27/213] ✓ BAT          | 105 weeks | RSI: 8.0 | surge: -38.85
# [ 28/213] ✓ BCH          | 105 weeks | RSI: 36.0 | surge: -18.94
# [ 29/213] ✓ BERA         |  59 weeks | RSI: 43.8 | surge: -14.18
# [ 30/213] ✓ BFUSD        |  32 weeks | RSI: 50.0 | surge: -8.95
# [ 31/213] ✓ BLUR         | 105 weeks | RSI: 26.8 | surge: -1.51
# [ 32/213] ✓ BNB          | 105 weeks | RSI: 27.8 | surge: 15.77
# [ 33/213] ✓ BONK         | 105 weeks | RSI: 33.8 | surge: -18.01
# [ 34/213] ✓ BTC          | 105 weeks | RSI: 28.3 | surge: 7.79
# [ 35/213] ✓ CAKE         | 105 weeks | RSI: 26.4 | surge: 22.87
# [ 36/213] ✓ CELO         | 105 weeks | RSI: 24.2 | surge: 37.38
# [ 37/213] ⚠  CFG          — only 1 weekly bars after resampling, skipping (need 26+)
# [ 38/213] ✓ CFX          | 105 weeks | RSI: 43.1 | surge: 82.43
# [ 39/213] ✓ CHZ          | 105 weeks | RSI: 51.9 | surge: -24.62
# [ 40/213] ✓ CKB          | 105 weeks | RSI: 22.1 | surge: -23.13
# [ 41/213] ✓ COMP         | 105 weeks | RSI: 28.9 | surge: -8.10
# [ 42/213] ✓ COW          |  72 weeks | RSI: 57.5 | surge: 9.43
# [ 43/213] ✓ CRV          | 105 weeks | RSI: 24.5 | surge: -14.29
# [ 44/213] ✓ CVX          | 105 weeks | RSI: 50.2 | surge: -27.95
# [ 45/213] ✓ DASH         | 105 weeks | RSI: 43.7 | surge: -3.53
# [ 46/213] ✓ DCR          | 105 weeks | RSI: 55.3 | surge: -23.74
# [ 47/213] ✓ DEXE         | 105 weeks | RSI: 71.2 | surge: 49.23
# [ 48/213] ✓ DGB          | 105 weeks | RSI: 19.9 | surge: 3.37
# [ 49/213] ✓ DOGE         | 105 weeks | RSI: 28.3 | surge: -7.80
# [ 50/213] ✓ DOT          | 105 weeks | RSI: 38.3 | surge: 16.17
# [ 51/213] ✓ DYDX         | 105 weeks | RSI: 18.4 | surge: -2.92
# [ 52/213] ✓ EDU          | 105 weeks | RSI: 26.0 | surge: -16.27
# [ 53/213] ✓ EGLD         | 105 weeks | RSI: 17.2 | surge: 3.81
# [ 54/213] ✓ EIGEN        |  77 weeks | RSI: 9.9 | surge: 22.89
# [ 55/213] ✓ ELF          |  57 weeks | RSI: 13.3 | surge: 13.73
# [ 56/213] ✓ ENA          | 103 weeks | RSI: 15.9 | surge: -14.03
# [ 57/213] ✓ ENJ          | 105 weeks | RSI: 41.3 | surge: 125.82
# [ 58/213] ✓ ENS          | 105 weeks | RSI: 21.2 | surge: 5.80
# [ 59/213] ⚠  ESP          — only 6 weekly bars after resampling, skipping (need 26+)
# [ 60/213] ✓ ETC          | 105 weeks | RSI: 19.9 | surge: -4.70
# [ 61/213] ✓ ETH          | 105 weeks | RSI: 28.2 | surge: 18.15
# [ 62/213] ✓ ETHFI        | 105 weeks | RSI: 28.5 | surge: 21.07
# [ 63/213] ✓ EURI         |  82 weeks | RSI: 42.7 | surge: -4.84
# [ 64/213] ✓ FDUSD        | 105 weeks | RSI: 58.1 | surge: -14.82
# [ 65/213] ✓ FET          | 105 weeks | RSI: 47.3 | surge: 75.72
# [ 66/213] ⚠  FF           — only 25 weekly bars after resampling, skipping (need 26+)
# [ 67/213] ✓ FIL          | 105 weeks | RSI: 31.2 | surge: 11.62
# [ 68/213] ✓ FLOKI        | 105 weeks | RSI: 32.0 | surge: -5.48
# [ 69/213] ✓ FLOW         | 105 weeks | RSI: 10.1 | surge: -6.10
# [ 70/213] ⚠  FOGO         — only 10 weekly bars after resampling, skipping (need 26+)
# [ 71/213] ✓ FORM         |  53 weeks | RSI: 44.3 | surge: 40.10
# [ 72/213] ⚠  FRAX         — only 10 weekly bars after resampling, skipping (need 26+)
# [ 73/213] ✓ GALA         | 105 weeks | RSI: 20.1 | surge: -17.90
# [ 74/213] ✓ GAS          | 105 weeks | RSI: 30.3 | surge: 3.30
# [ 75/213] ✓ GLM          | 105 weeks | RSI: 34.7 | surge: -13.68
# [ 76/213] ✓ GMX          | 105 weeks | RSI: 29.5 | surge: -0.09
# [ 77/213] ✓ GNO          | 105 weeks | RSI: 52.4 | surge: 10.91
# [ 78/213] ✓ GRT          | 105 weeks | RSI: 24.7 | surge: 0.62
# [ 79/213] ✓ HBAR         | 105 weeks | RSI: 27.5 | surge: 1.72
# [ 80/213] ✓ HOME         |  41 weeks | RSI: 47.2 | surge: -16.13
# [ 81/213] ✓ HOT          | 105 weeks | RSI: 42.4 | surge: 64.09
# [ 82/213] ✓ ICP          | 105 weeks | RSI: 40.9 | surge: 0.27
# [ 83/213] ✓ IMX          | 105 weeks | RSI: 26.5 | surge: 7.09
# [ 84/213] ✓ INJ          | 105 weeks | RSI: 25.6 | surge: -3.31
# [ 85/213] ✓ IOTA         | 105 weeks | RSI: 27.6 | surge: -8.87
# [ 86/213] ✓ IOTX         | 105 weeks | RSI: 27.5 | surge: -1.53
# [ 87/213] ✓ JASMY        | 105 weeks | RSI: 43.3 | surge: -5.32
# [ 88/213] ✓ JST          | 105 weeks | RSI: 76.1 | surge: 3.37
# [ 89/213] ✓ JTO          | 105 weeks | RSI: 41.6 | surge: 26.75
# [ 90/213] ✓ JUP          | 105 weeks | RSI: 39.0 | surge: 29.22
# [ 91/213] ✓ KAIA         |  73 weeks | RSI: 33.8 | surge: -19.19
# [ 92/213] ✓ KAITO        |  57 weeks | RSI: 25.2 | surge: 20.87
# [ 93/213] ✓ KAVA         | 105 weeks | RSI: 27.3 | surge: 39.13
# [ 94/213] ⚠  KITE         — only 20 weekly bars after resampling, skipping (need 26+)
# [ 95/213] ✓ KMNO         |  46 weeks | RSI: 17.9 | surge: 3.61
# [ 96/213] ✓ KSM          | 105 weeks | RSI: 24.5 | surge: -4.53
# [ 97/213] ✓ LA           |  37 weeks | RSI: 35.3 | surge: 4.10
# [ 98/213] ✓ LDO          | 105 weeks | RSI: 18.5 | surge: -6.57
# [ 99/213] ✓ LINEA        |  28 weeks | RSI: 16.8 | surge: 44.20
# [100/213] ✓ LINK         | 105 weeks | RSI: 24.5 | surge: 4.09
# [101/213] ✓ LIT          |  48 weeks | RSI: 51.7 | surge: -34.08
# [102/213] ✓ LPT          | 105 weeks | RSI: 23.8 | surge: -5.70
# [103/213] ✓ LTC          | 105 weeks | RSI: 17.0 | surge: 5.23
# [104/213] ✓ LUNA         | 105 weeks | RSI: 4.9 | surge: -43.89
# [105/213] ✓ LUNC         | 105 weeks | RSI: 39.4 | surge: 81.14
# [106/213] ✓ MANA         | 105 weeks | RSI: 31.8 | surge: -7.89
# [107/213] ⚠  MANTRA       — only 3 weekly bars after resampling, skipping (need 26+)
# [108/213] ✓ MASK         | 105 weeks | RSI: 34.1 | surge: 26.61
# [109/213] ✓ ME           |  67 weeks | RSI: 17.2 | surge: 1.34
# [110/213] ⚠  MET          — only 19 weekly bars after resampling, skipping (need 26+)
# [111/213] ✓ MINA         | 105 weeks | RSI: 26.7 | surge: 15.29
# [112/213] ⚠  MORPHO       — only 25 weekly bars after resampling, skipping (need 26+)
# [113/213] ✓ MOVE         |  67 weeks | RSI: 23.1 | surge: 3.43
# [114/213] ✓ NEAR         | 105 weeks | RSI: 38.4 | surge: 38.04
# [115/213] ✓ NEO          | 105 weeks | RSI: 22.4 | surge: 8.93
# [116/213] ✓ NEXO         | 105 weeks | RSI: 42.9 | surge: 1.16
# [117/213] ⚠  NIGHT        — only 2 weekly bars after resampling, skipping (need 26+)
# [118/213] ✓ NMR          | 105 weeks | RSI: 24.8 | surge: -20.22
# [119/213] ✓ NXPC         |  45 weeks | RSI: 21.0 | surge: 23.92
# [120/213] ✓ OM           | 103 weeks | RSI: 39.7 | surge: 84.90
# [121/213] ✓ ONDO         |  50 weeks | RSI: 19.7 | surge: 2.19
# [122/213] ✓ OP           | 105 weeks | RSI: 22.6 | surge: 23.28
# [123/213] ⚠  OPN          — only 3 weekly bars after resampling, skipping (need 26+)
# [124/213] ✓ ORCA         |  68 weeks | RSI: 40.9 | surge: 16.97
# [125/213] ✓ ORDI         | 105 weeks | RSI: 29.9 | surge: -19.95
# [126/213] ✓ PAXG         | 105 weeks | RSI: 56.0 | surge: -95.24
# [127/213] ✓ PENDLE       | 105 weeks | RSI: 26.3 | surge: 0.64
# [128/213] ✓ PENGU        |  66 weeks | RSI: 34.2 | surge: 6.46
# [129/213] ✓ PEPE         | 105 weeks | RSI: 42.6 | surge: -11.67
# [130/213] ✓ PLUME        |  31 weeks | RSI: 30.2 | surge: 8.40
# [131/213] ✓ PNUT         |  71 weeks | RSI: 23.7 | surge: -30.08
# [132/213] ✓ POL          |  80 weeks | RSI: 43.0 | surge: -4.36
# [133/213] ✓ POLYX        | 105 weeks | RSI: 41.0 | surge: 50.80
# [134/213] ✓ PROVE        |  33 weeks | RSI: 33.8 | surge: -10.17
# [135/213] ✓ PUMP         |  28 weeks | RSI: 39.8 | surge: -31.18
# [136/213] ✓ PYTH         | 105 weeks | RSI: 31.6 | surge: -28.07
# [137/213] ✓ QNT          | 105 weeks | RSI: 48.2 | surge: 113.69
# [138/213] ✓ QTUM         | 105 weeks | RSI: 28.0 | surge: -11.42
# [139/213] ✓ RAY          | 105 weeks | RSI: 29.0 | surge: -3.23
# [140/213] ✓ RENDER       |  87 weeks | RSI: 52.6 | surge: -29.37
# [141/213] ✓ REQ          | 105 weeks | RSI: 18.3 | surge: 135.55
# [142/213] ⚠  RLUSD        — only 9 weekly bars after resampling, skipping (need 26+)
# [143/213] ⚠  ROBO         — only 3 weekly bars after resampling, skipping (need 26+)
# [144/213] ✓ ROSE         | 105 weeks | RSI: 49.5 | surge: -7.92
# [145/213] ✓ RSR          | 105 weeks | RSI: 23.3 | surge: 18.29
# [146/213] ✓ RUNE         | 105 weeks | RSI: 31.0 | surge: -2.55
# [147/213] ✓ RVN          | 105 weeks | RSI: 25.8 | surge: -8.30
# [148/213] ✓ S            |  62 weeks | RSI: 23.1 | surge: 18.90
# [149/213] ✓ SAHARA       |  39 weeks | RSI: 44.7 | surge: 83.31
# [150/213] ✓ SAND         | 105 weeks | RSI: 34.5 | surge: -9.73
# [151/213] ✓ SC           | 105 weeks | RSI: 26.0 | surge: -5.80
# [152/213] ✓ SEI          | 105 weeks | RSI: 12.8 | surge: -20.05
# [153/213] ⚠  SENT         — only 9 weekly bars after resampling, skipping (need 26+)
# [154/213] ✓ SFP          | 105 weeks | RSI: 41.5 | surge: 5.13
# [155/213] ✓ SHIB         | 105 weeks | RSI: 33.4 | surge: -16.22
# [156/213] ✓ SIGN         |  47 weeks | RSI: 63.3 | surge: 129.01
# [157/213] ✓ SKY          |  27 weeks | RSI: 62.5 | surge: -107.29
# [158/213] ✓ SNX          | 105 weeks | RSI: 35.0 | surge: 11.56
# [159/213] ✓ SOL          | 105 weeks | RSI: 29.1 | surge: 18.55
# [160/213] ✓ SPK          |  40 weeks | RSI: 49.1 | surge: -15.26
# [161/213] ✓ STRK         | 105 weeks | RSI: 10.7 | surge: -6.03
# [162/213] ✓ STX          | 105 weeks | RSI: 42.8 | surge: -15.18
# [163/213] ✓ SUI          | 105 weeks | RSI: 31.4 | surge: -4.73
# [164/213] ✓ SUN          | 105 weeks | RSI: 37.2 | surge: 105.45
# [165/213] ✓ SUPER        | 105 weeks | RSI: 3.7 | surge: -18.97
# [166/213] ✓ SUSHI        | 105 weeks | RSI: 26.3 | surge: -0.82
# [167/213] ✓ SXT          |  46 weeks | RSI: 26.8 | surge: -21.18
# [168/213] ✓ SYRUP        |  46 weeks | RSI: 46.5 | surge: -17.60
# [169/213] ✓ T            | 105 weeks | RSI: 26.1 | surge: 16.87
# [170/213] ✓ TAO          | 102 weeks | RSI: 48.1 | surge: 91.76
# [171/213] ✓ TFUEL        | 105 weeks | RSI: 25.1 | surge: -10.18
# [172/213] ✓ THETA        | 105 weeks | RSI: 21.8 | surge: -17.41
# [173/213] ✓ TIA          | 105 weeks | RSI: 27.2 | surge: 2.61
# [174/213] ✓ TON          |  85 weeks | RSI: 34.1 | surge: -27.12
# [175/213] ✓ TRB          | 105 weeks | RSI: 34.6 | surge: 4.85
# [176/213] ✓ TRUMP        |  61 weeks | RSI: 27.7 | surge: -41.24
# [177/213] ✓ TRX          | 105 weeks | RSI: 64.9 | surge: 70.66
# [178/213] ✓ TURBO        |  79 weeks | RSI: 27.8 | surge: -29.41
# [179/213] ✓ TUSD         | 105 weeks | RSI: 68.1 | surge: 23.07
# [180/213] ✓ TWT          | 105 weeks | RSI: 19.9 | surge: 9.38
# [181/213] ✓ UNI          | 105 weeks | RSI: 29.4 | surge: -12.88
# [182/213] ✓ USD1         |  44 weeks | RSI: 53.1 | surge: 14.83
# [183/213] ✓ USDC         | 105 weeks | RSI: 52.9 | surge: 8.89
# [184/213] ✓ USDE         |  28 weeks | RSI: 60.0 | surge: -12.69
# [185/213] ⚠  USDT         — only 18 weekly bars after resampling, skipping (need 26+)
# [186/213] ✓ VANA         |  66 weeks | RSI: 9.3 | surge: -11.28
# [187/213] ✓ VET          | 105 weeks | RSI: 20.3 | surge: 7.24
# [188/213] ✓ VIRTUAL      |  50 weeks | RSI: 45.5 | surge: 4.62
# [189/213] ✓ VTHO         | 105 weeks | RSI: 19.6 | surge: -12.01
# [190/213] ✓ W            | 103 weeks | RSI: 8.9 | surge: -6.02
# [191/213] ⚠  WAL          — only 24 weekly bars after resampling, skipping (need 26+)
# [192/213] ⚠  WAVES        — only 14 weekly bars after resampling, skipping (need 26+)
# [193/213] ✓ WIF          | 105 weeks | RSI: 22.9 | surge: -11.48
# [194/213] ✓ WLD          | 105 weeks | RSI: 20.3 | surge: -38.08
# [195/213] ✓ WLFI         |  29 weeks | RSI: 34.4 | surge: -47.53
# [196/213] ✓ XEC          | 105 weeks | RSI: 19.9 | surge: -21.72
# [197/213] ✓ XLM          | 105 weeks | RSI: 22.3 | surge: 22.92
# [198/213] ✓ XNO          | 105 weeks | RSI: 15.3 | surge: 28.01
# [199/213] ✓ XPL          |  26 weeks | RSI: 39.2 | surge: -16.55
# [200/213] ✓ XRP          | 105 weeks | RSI: 27.6 | surge: 15.47
# [201/213] ✓ XTZ          | 105 weeks | RSI: 40.6 | surge: 14.15
# [202/213] ✓ XUSD         |  53 weeks | RSI: 51.1 | surge: 13.76
# [203/213] ✓ XVG          | 105 weeks | RSI: 43.2 | surge: -30.17
# [204/213] ✓ XVS          | 105 weeks | RSI: 32.5 | surge: -13.22
# [205/213] ✓ YFI          | 105 weeks | RSI: 28.6 | surge: 30.31
# [206/213] ⚠  ZAMA         — only 7 weekly bars after resampling, skipping (need 26+)
# [207/213] ✓ ZEC          | 105 weeks | RSI: 22.9 | surge: 13.68
# [208/213] ✓ ZEN          | 105 weeks | RSI: 38.1 | surge: 0.23
# [209/213] ✓ ZIL          | 105 weeks | RSI: 34.5 | surge: -0.01
# [210/213] ✓ ZK           |  92 weeks | RSI: 28.2 | surge: -5.42
# [211/213] ✓ ZRO          |  92 weeks | RSI: 59.2 | surge: 8.81
# [212/213] ✓ ZRX          | 105 weeks | RSI: 36.2 | surge: -0.60
# [213/213] ⚠  币安人生         — only 11 weekly bars after resampling, skipping (need 26+)
# ======================================================================
#
# 💾 Merging and saving...
#
# ======================================================================
# SUMMARY
# ======================================================================
# ✅ Successful : 192 coins
# ❌ Failed     : 21 coins
# 📊 Total rows : 17,482  (weekly bars)
# 📅 Date range : 2024-03-22 → 2026-03-20
# ⏱  Time       : 49.0s (0.8 min)
#
# Column breakdown:
#   OHLCV + meta  : 19
#   Indicators    : 59  ← includes surge_score
#   Future returns: 5  (Next_1w … Next_8w)
#   TOTAL         : 83
#
# 📁 Output: weekly_crypto_with_indicators.csv
#    Size  : 14.8 MB
